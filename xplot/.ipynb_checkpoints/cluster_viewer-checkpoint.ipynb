-- %%
f = torch.DiskFile('/home/ubuntu/bbimgath/clustered','r')
f:binary()

-- %%
ns = 1501
ntr = 980

-- %%
dat = torch.Tensor(ns,ntr)

-- %%
raw = f:readFloat(ns*ntr)

-- %%
for j = 1, ntr do
        for i = 1, ns do
                dat[i][j] = raw[i + (j-1)*ns]
        end
end

-- %%
itorch.image(dat)
-- Out:
-- Console does not support images

-- %%
-- colors a 2D tensor
function colorize(t)
    local r = 0
    local g = 0
    local b = 0
    local temp = torch.Tensor(3, t:size(1), t:size(2))
    
    t:div(torch.max(t))
    
    for i = 1, t:size(1) do
        for j = 1, t:size(2) do
            temp[1][i][j] = 
            temp[2][i][j] = 
            temp[3][i][j] = 
        end
    end
    
    return temp
end

-- %%
--[[
require 'image'
image.save('clustered.jpg', dat)
]]--
